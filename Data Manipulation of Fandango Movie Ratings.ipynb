# %% [markdown]
# # Data Manipulation of Fandango Movie Ratings
#
# ## Data
#
# Our data set comes from the data journalism site, [FiveThirtyEight](https://fivethirtyeight.com/), and was used for a 2015 article titled '[Be Suspicious Of Online Movie Ratings, Especially Fandango’s](https://fivethirtyeight.com/features/fandango-movies-ratings/)'.
#
# In this project we will use Pandas to explore the dataset from the article.  Our data will be slightly different than the article as it appears they were working with a larger set of data
#
# First, let's import our basic libraries and set the option to display all columns in the data.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# Import the data from the `fandango.csv` file.

# %%
fandango = pd.read_csv('fandango.csv')
fandango
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                     86          66              7.1   7.8             5.0
# ...

# %% [markdown]
# As we can see, this data contains the review scores for four review sites: Rotten Tomatoes, Metacritic, IMDB, and Fandango.  These sites use different methodologies in terms of ratings, and Rotten Tomatoes and Metacritic have separate critic scores and user scores.
#
# According to the 538 article, the columns with 'norm' in the column name are scores that have been normalized to the five-star rating scale that Fandango uses and the columns with 'norm_round' in the column name are those columns rounded to the nearest half-star.

# %% [markdown]
# Use `.info()` to obtain more information about the columns, number of entries, number of missing values (if any), and the data type for each column.

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Fandango_Stars              146 non-null    float64
#  7   Fandango_Ratingvalue        146 non-null    float64
#  8   RT_norm                     146 non-null    float64
#  9   RT_user_norm                146 non-null    float64
#  10  Metacritic_norm             146 non-null    float64
#  11  Metacritic_user_nom         146 non-null    float64
#  12  IMDB_norm                   146 non-null    float64
# ...

# %% [markdown]
# Use `.describe()` to obtain a statistical overview of the data.

# %%
fandango.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Fandango_Stars  Fandango_Ratingvalue     RT_norm  \
# count  146.000000      146.000000            146.000000  146.000000
# mean     6.736986        4.089041              3.845205    3.042466
# std      0.958736        0.540386              0.502831    1.508440
# ...

# %% [markdown]
# There is already interesting information that we can see from this statistical overview if we compare Fandango's star ratings with the other review sites in terms of the mean, standard deviation, and minimum.

# %% [markdown]
# **Q1:** The article begins by talking about the movie: `Fantastic Four (2015)`. Index the `fandango` DataFrame and select only the row for this film.

# %%
Q1 = fandango[fandango['FILM'] == 'Fantastic Four (2015)']
Q1
# Out:
#                      FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 48  Fantastic Four (2015)               9                   20          27
#
#     Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 48              2.5   4.0             3.0                   2.7     0.45
#
#     RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 48           1.0             1.35                 1.25        2.0
#
#     RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 48            0.5                 1.0                    1.5
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 48                         1.5              2.0                         421
#
#     IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 48                 39838            6288                  0.3

# %% [markdown]
# As we can see, the `Fandango_Stars` rating is `3.0` while if we look at the other ratings from the other review sites (looking at the columns with `norm` in the column name) we will notice the review scores being much lower.

# %% [markdown]
# **Q2:** Select the `Fandango_Stars` column as a Series.  What is the minimum score in the Series?

# %%
Q2A = fandango['Fandango_Stars']
Q2A
# Out:
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      3.5
#       ...
# 141    4.0
# 142    3.5
# 143    3.5
# 144    3.5
# 145    3.5
# Name: Fandango_Stars, Length: 146, dtype: float64

# %%
Q2B = Q2A.min()
Q2B
# Out:
# 3.0

# %% [markdown]
# **Q3:** What is the maximum `Fandango_Stars` score in the `fandango` data?

# %%
Q3 = Q2A.max()
Q3
# Out:
# 5.0

# %% [markdown]
# If we were to check the minimum and maximum ranges for the other review sites, we should notice that the range of scores for the Fandango star ratings is much more narrow.

# %% [markdown]
# **Q4:** What is the minimum score for `RT_norm_round`, `Metacritic_norm_round`, and `IMDB_norm_round`?

# %%
Q4 = fandango[['RT_norm_round', 'Metacritic_norm_round', 'IMDB_norm_round']].min().tolist()
Q4
# Out:
# [0.5, 0.5, 2.0]

# %% [markdown]
# **Q5:** What is the maximum score for `RT_norm_round`, `Metacritic_norm_round`, and `IMDB_norm_round`?

# %%
Q5 = fandango[['RT_norm_round', 'Metacritic_norm_round', 'IMDB_norm_round']].max().tolist()
Q5
# Out:
# [5.0, 4.5, 4.5]

# %% [markdown]
# As we saw above, the lowest rating for Fandango for a movie was three stars, while the rounded, normalized review stars for the other sites were much lower. The other sites also have a much wider range of values.
#
# Run the cell below to view boxplots of the various site's star ratings.  Notice the smaller range and higher minimum for the Fandango star ratings.

# %%
import matplotlib.pyplot as plt

data = fandango[['Fandango_Stars','RT_norm_round','Metacritic_norm_round','IMDB_norm_round']]
labels = ['Fandango', 'RT', 'Metacritic','IMDB']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(9, 4))

# rectangular box plot
bplot1 = ax.boxplot(data,
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks

ax.set_title('Movie Stars Box Plots')

plt.show()

# %% [markdown]
# **Q6:** Using `value_counts`, what is the breakdown of counts for the `Fandango_Stars` column sorted by the index?
#
# What is the breakdown of relative frequencies (percentages) of the unique values sorted by the index and rounded to 3 decimal places?

# %%
Q6A = fandango['Fandango_Stars'].value_counts().sort_index()
Q6A
# Out:
# 3.0    12
# 3.5    27
# 4.0    41
# 4.5    55
# 5.0    11
# Name: Fandango_Stars, dtype: int64

# %%
Q6B = fandango['Fandango_Stars'].value_counts(normalize=True).sort_index().round(3)
Q6B
# Out:
# 3.0    0.082
# 3.5    0.185
# 4.0    0.281
# 4.5    0.377
# 5.0    0.075
# Name: Fandango_Stars, dtype: float64

# %% [markdown]
# **Q7:** Given the output for `Q6B`, what is the sum of the frequency of values for 4 stars or more?

# %%
Q7 = Q6B[Q6B.index >= 4].sum().round(2)
Q7
# Out:
# 0.73

# %% [markdown]
# To give a comparison to the output above, the sum of frequency values for 4 stars or more for the other sites are as follows:
#
# - RT_norm_round = 0.419
# - Metacritic_norm_round = 0.274
# - IMDB_norm_round = 0.233
#
# We see that the output for `Q7` is higher, which is one indication that Fandango rates their movies with higher overall scores.

# %% [markdown]
# **Q8:** In the article, the author "normalized" the data by turning the sites with 0-100 ranges to 0-5 ranges.  Create a Series that takes the values in the `RottenTomatoes` column and normalizes them to 0-5 ranges.
#
# For example: A score of 100 will equal a new score of 5.00, a score of 50 will equal a new score of 2.50, a score of 20 will equal a new score of 1, etc.

# %%
Q8 = (fandango['RottenTomatoes']/20).round(2)
Q8
# Out:
# 0      3.70
# 1      4.25
# 2      4.00
# 3      0.90
# 4      0.70
#        ...
# 141    4.35
# 142    4.85
# 143    4.85
# 144    5.00
# 145    4.35
# Name: RottenTomatoes, Length: 146, dtype: float64

# %%
(fandango['RT_norm'] != Q8).sum()
# Out:
# 0

# %% [markdown]
# **Q9:**
# - First create a copy of the `fandango` DataFrame.
# - Create a new column in this DataFrame called `f_rt_norm` that is the `Fandango_Stars` column minus the `RT_norm_round` column.
# - Select only the films where the `RT_norm_round` was higher (the `f_rt_norm` is negative).

# %%
Q9A = fandango.copy()
Q9A['f_rt_norm'] = Q9A['Fandango_Stars'] - Q9A['RT_norm_round']
Q9B = Q9A[Q9A['f_rt_norm'] < 0]
Q9B
# Out:
#                                                 FILM  RottenTomatoes  \
# 7                                    Top Five (2014)              86
# 8                       Shaun the Sheep Movie (2015)              99
# 12                                  Leviathan (2014)              99
# 28                                 Wild Tales (2014)              96
# 30                                   Red Army (2015)              96
# 40                  I'll See You In My Dreams (2015)              94
# 41                                   Timbuktu (2015)              99
# 42                                 About Elly (2015)              97
# 43                The Diary of a Teenage Girl (2015)              95
# 65                                    Birdman (2014)              92
# 66                                   The Gift (2015)              93
# 69                                 Mr. Turner (2014)              98
# 70                   Seymour: An Introduction (2015)             100
# ...

# %% [markdown]
# **Q10 & Q11:**
# - Perform the same action as above creating two new columns by subtracting the `Metacritic_norm_round` and `IMDB_norm_round` from `Fandango_Stars` and calling the columns `f_mc_norm` and `f_imdb_norm` respectively and in that order.
# - Select the rows where `f_mc_norm` is negative.
# - Select the rows where `f_imdb_norm` is negative.

# %%
Q9A['f_mc_norm'] = Q9A['Fandango_Stars'] - Q9A['Metacritic_norm_round']
Q10 = Q9A[Q9A['f_mc_norm'] < 0]
Q10
# Out:
#                                           FILM  RottenTomatoes  \
# 12                            Leviathan (2014)              99
# 41                             Timbuktu (2015)              99
# 42                           About Elly (2015)              97
# 43          The Diary of a Teenage Girl (2015)              95
# 65                              Birdman (2014)              92
# 69                           Mr. Turner (2014)              98
# 112                          It Follows (2015)              96
# 113                       Inherent Vice (2014)              73
# 114                 A Most Violent Year (2014)              90
# 115                   While We're Young (2015)              83
# 116                Clouds of Sils Maria (2015)              89
# 119                             Phoenix (2015)              99
# 120                        The Wolfpack (2015)              84
# 122                           Tangerine (2015)              95
# ...

# %%
Q9A['f_imdb_norm'] = Q9A['Fandango_Stars'] - Q9A['IMDB_norm_round']
Q11 = Q9A[Q9A['f_imdb_norm'] < 0]
Q11
# Out:
#                                           FILM  RottenTomatoes  \
# 112                          It Follows (2015)              96
# 113                       Inherent Vice (2014)              73
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 112                   65          83              7.5   6.9             3.0
# 113                   52          81              7.4   6.7             3.0
# 144                   81          90              7.3   7.8             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  Metacritic_norm  \
# 112                   2.9     4.80          3.25             4.15
# 113                   2.9     3.65          2.60             4.05
# 144                   3.5     5.00          4.05             4.50
#
#      Metacritic_user_nom  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %% [markdown]
# **Q12:** What are the means of the `f_rt_norm`, `f_mc_norm`, and `f_imdb_norm` columns rounded to 3 decimal places.

# %%
Q12 = Q9A[['f_rt_norm','f_mc_norm','f_imdb_norm']].mean().round(3).tolist()
Q12
# Out:
# [1.024, 1.116, 0.709]

# %% [markdown]
# **Q13:** What are the median values of the `f_rt_norm`, `f_mc_norm`, and `f_imdb_norm` columns.

# %%
Q13 = Q9A[['f_rt_norm','f_mc_norm','f_imdb_norm']].median().tolist()
Q13
# Out:
# [1.0, 1.0, 0.5]

# %% [markdown]
# **Q14:** The article mentions the movie `Avengers: Age of Ultron (2015)`.  Select this film in the `fandango` data.

# %%
Q14 = fandango[fandango['FILM'] == 'Avengers: Age of Ultron (2015)']
Q14
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
#
#    RT_norm  RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 0      3.7           4.3              3.3                 3.55        3.9
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0            3.5                 4.5                    3.5
#
#    Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 0                         3.5              4.0                        1330
#
#    IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 0                271107           14846                  0.5

# %% [markdown]
# **Q15:** Select only the `FILM`, `Fandango_Stars`, and `Fandango_Ratingvalue` columns from the above.

# %%
Q15 = Q14[['FILM', 'Fandango_Stars', 'Fandango_Ratingvalue']]
Q15
# Out:
#                              FILM  Fandango_Stars  Fandango_Ratingvalue
# 0  Avengers: Age of Ultron (2015)             5.0                   4.5

# %% [markdown]
# As was mentioned in the article, we can see that this movie gained an entire half star between the actual rating score and the stars score.

# %% [markdown]
# **Q16:** Index the `fandango` DataFrame and select all movies with an `IMDB` score of 8 or higher.

# %%
Q16 = fandango[fandango['IMDB'] >= 8]
Q16
# Out:
#                                       FILM  RottenTomatoes  \
# 14               The Imitation Game (2014)              90
# 28                       Wild Tales (2014)              96
# 42                       About Elly (2015)              97
# 76           Straight Outta Compton (2015)              90
# 86   Me and Earl and The Dying Girl (2015)              81
# 88               Mad Max: Fury Road (2015)              97
# 95            The Salt of the Earth (2015)              96
# 96                  Song of the Sea (2014)              99
# 129                             Amy (2015)              97
# 140                      Inside Out (2015)              98
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 14                    92          73              8.2   8.1             5.0
# 28                    92          77              8.8   8.2             4.5
# 42                    86          87              9.6   8.2             4.0
# ...

# %% [markdown]
# **Q17:** Index the `fandango` DataFrame and select all movies with a `RottenTomatoes` score of 100.

# %%
Q17 = fandango[fandango['RottenTomatoes'] == 100]
Q17
# Out:
#                                           FILM  RottenTomatoes  \
# 70             Seymour: An Introduction (2015)             100
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 70                    87          83              6.0   7.7             4.5
# 144                   81          90              7.3   7.8             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  Metacritic_norm  \
# 70                    4.2      5.0          4.35             4.15
# 144                   3.5      5.0          4.05             4.50
#
#      Metacritic_user_nom  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 70                  3.00       3.85            5.0                 4.5
# 144                 3.65       3.90            5.0                 4.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# ...

# %% [markdown]
# **Q18:** Index the `fandango` DataFrame and select all movies with a `Metacritic` score less than 20.

# %%
Q18 = fandango[fandango['Metacritic'] < 20]
Q18
# Out:
#                               FILM  RottenTomatoes  RottenTomatoes_User  \
# 133  Paul Blart: Mall Cop 2 (2015)               5                   36
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 133          13              2.4   4.3             3.5                   3.5
#
#      RT_norm  RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 133     0.25           1.8             0.65                  1.2       2.15
#
#      RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 133            0.5                 2.0                    0.5
#
#      Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 133                         1.0              2.0                         211
#
#      IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 133                 15004            3054                  0.0

# %% [markdown]
# **Q19:** Index the `fandango` DataFrame and select all movies with a `RottenTomatoes_User` greater than 85, `Metacritic_User` score greater than 8.5, and an `IMDB` score greater than 8.5.

# %%
Q19 = fandango[(fandango['RottenTomatoes_User'] > 85) & (fandango['Metacritic_User'] > 8.5) & (fandango['IMDB'] > 8.5)]
Q19
# Out:
#                   FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 140  Inside Out (2015)              98                   90          94
#
#      Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 140              8.9   8.6             4.5                   4.5      4.9
#
#      RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 140           4.5              4.7                 4.45        4.3
#
#      RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 140            5.0                 4.5                    4.5
#
#      Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 140                         4.5              4.5                         807
#
#      IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 140                 96252           15749                  0.0

# %% [markdown]
# **Q20:** Sort the `fandango` DataFrame by the number of Fandango votes (in descending order) and save this new DataFrame.  Select only the films with more than 30,000 votes in descending order by number of votes.

# %%
fandango_sorted_value = fandango.sort_values(by='Fandango_votes', ascending=False)
Q20 = fandango_sorted_value[fandango_sorted_value['Fandango_votes'] > 30000]
Q20
# Out:
#                             FILM  RottenTomatoes  RottenTomatoes_User  \
# 97   Fifty Shades of Grey (2015)              25                   42
# 130        Jurassic World (2015)              71                   81
# 72        American Sniper (2015)              72                   85
# 73              Furious 7 (2015)              81                   84
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 97           46              3.2   4.2             4.0                   3.9
# 130          59              7.0   7.3             4.5                   4.5
# 72           72              6.6   7.4             5.0                   4.8
# 73           67              6.8   7.4             5.0                   4.8
#
#      RT_norm  RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 97      1.25          2.10             2.30                  1.6       2.10
# ...

# %% [markdown]
# **Q21:** Using the above DataFrame, select only the films that have a `Fandango_Stars` rating of `5`.

# %%
Q21 = Q20[Q20['Fandango_Stars'] == 5]
Q21
# Out:
#                       FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 72  American Sniper (2015)              72                   85          72
# 73        Furious 7 (2015)              81                   84          67
#
#     Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 72              6.6   7.4             5.0                   4.8     3.60
# 73              6.8   7.4             5.0                   4.8     4.05
#
#     RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 72          4.25             3.60                  3.3        3.7
# 73          4.20             3.35                  3.4        3.7
#
#     RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 72            3.5                 4.5                    3.5
# 73            4.0                 4.0                    3.5
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# ...

# %% [markdown]
# **Q22:** The article from 538 goes into detail about the rounding problem with the Fandango star scores.  Let's see if we can do better.
# - First create a copy of the `fandango` DataFrame.
# - Create a new column called `Fandango_Stars_Revised` that rounds the `Fandango_Ratingvalue` column to the nearest half a star.  For example, 3.2 would round to 3.0, 3.3 would round to 3.5, 3.7 would round to 3.5, 3.8 would round to 4.0, etc.
# - Select only the `FILM`, `Fandango_Ratingvalue`, and `Fandango_Stars_Revised` columns.

# %%
Q22A = fandango.copy()
Q22A['Fandango_Stars_Revised'] = (Q22A['Fandango_Ratingvalue']*2).round()/2
Q22B = Q22A[['FILM', 'Fandango_Ratingvalue','Fandango_Stars_Revised']]
Q22B

#code check
# Q22B[Q22B['Fandango_Ratingvalue'] == 3.7]
Q22B[Q22B['Fandango_Ratingvalue'] == 3.8]
# Out:
#                   FILM  Fandango_Ratingvalue  Fandango_Stars_Revised
# 77     Vacation (2015)                   3.8                     4.0
# 78      Chappie (2015)                   3.8                     4.0
# 80  Paper Towns (2015)                   3.8                     4.0
# 81     Big Eyes (2014)                   3.8                     4.0
# 83    Self/less (2015)                   3.8                     4.0

# %% [markdown]
# **Q23:** Calculate the sum for the `Fandango_Difference` column.

# %%
Q23 = fandango['Fandango_Difference'].sum().round(2)
Q23
# Out:
# 35.6

# %% [markdown]
# **Q24:**
# - Create a new Series called by subtracting `Fandango_Ratingvalue` from `Fandango_Stars_Revised` from the DataFrame in Q22.
# - Calculate the sum of this Series.

# %%
ser = Q22A['Fandango_Stars_Revised'] - Q22A['Fandango_Ratingvalue']
Q24 = ser.sum().round(2)
Q24
# Out:
# -0.4

# %% [markdown]
# We see that the sum for `ser` is much less than the sum of the `Fandango_Difference` column.  This makes sense as our `Fandango_Stars_Revised` column rounded to the closest half star instead of always rounding up like was done with the `Fandango_Stars` column as discussed in the 538 article.

# %% [markdown]
# **Q25:** Set the index of `fandango` as the `FILM` column and sort the index in ascending order.

# %%
Q25 = fandango.set_index('FILM').sort_index()
Q25
# Out:
#                                   RottenTomatoes  RottenTomatoes_User  \
# FILM
# '71 (2015)                                    97                   82
# 5 Flights Up (2015)                           52                   47
# A Little Chaos (2015)                         40                   47
# A Most Violent Year (2014)                    90                   69
# About Elly (2015)                             97                   86
# ...                                          ...                  ...
# What We Do in the Shadows (2015)              96                   86
# When Marnie Was There (2015)                  89                   89
# While We're Young (2015)                      83                   52
# Wild Tales (2014)                             96                   92
# Woman in Gold (2015)                          52                   81
#
#                                   Metacritic  Metacritic_User  IMDB  \
# FILM
# ...
